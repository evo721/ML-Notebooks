# %%
# !pip install datasets[vision]

# %%
# !pip install torch
#!pip install diffusers
# !pip install transformers
# !pip install ftfy
# !pip install spacy
# !pip install accelerate
# !pip install datasets
# !pip install bitsandbytes

# %%
# !pip install git+https://github.com/huggingface/diffusers

# %%
import numpy
import json
import time
from IPython.display import Markdown, display
import matplotlib.pyplot as plt
import pandas as pd
import torch
import accelerate
from datasets import load_dataset, Image
import torchvision
import os
import shutil

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from diffusers import DiffusionPipeline

#pipeline = DiffusionPipeline.from_pretrained("")

# %%
from google.colab import output
output.enable_custom_widget_manager()

# %%
from huggingface_hub import notebook_login

notebook_login()

# %%
# !accelerate config default

# %%
#from datasets import load_dataset, Image

# Load the dataset
#dataset = load_dataset("matterr/product-10k-part1", split="train")

# Save the dataset to a temporary directory on disk
#temp_dir = "my_dataset"
#if os.path.exists(temp_dir):
    #shutil.rmtree(temp_dir)
#os.makedirs(temp_dir)
#dataset.save_to_disk(temp_dir)

#dataset[0]["image"]

# %%
dataset = load_dataset("imagefolder", data_dir="/content/drive/Shareddrives/Unbound/tests/cocacola_test", split="train")
train_data = dataset
train_data[0]["image"]

# %%
from datasets import load_dataset, Image
dataset = load_dataset("matterr/product-10k-part1", split="train")
dataset[0]["image"]

# %%
#load from checkpoint

# %%
# %cd /content 

# Define the paths to the model and output directories
MODEL_NAME = "stabilityai/stable-diffusion-2-inpainting" 
OUTPUT_DIR = "/output/data_sample"

# Launch the training script using the dataset
# !accelerate launch inpainting_train.py \
  --pretrained_model_name_or_path=$MODEL_NAME \
  --instance_data_dir=$temp_dir \
  --output_dir=$OUTPUT_DIR \
  --instance_prompt="a photo of sks dog" \
  --resolution=512 \
  --train_batch_size=1 \
  --gradient_accumulation_steps=1 \
  --learning_rate=5e-6 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --max_train_steps=400

# %%
MODEL_NAME="stabilityai/stable-diffusion-2-inpainting"
INSTANCE_DIR="/content/drive/Shareddrives/Unbound/tests/cocacola_test"
OUTPUT_DIR="/output/data_sample"

# !accelerate launch inpainting_train.py \
  --pretrained_model_name_or_path=$MODEL_NAME  \
  --instance_data_dir=$INSTANCE_DIR \
  --output_dir=$OUTPUT_DIR \
  --instance_prompt="a photo of sks dog" \
  --resolution=512 \
  --train_batch_size=1 \
  --gradient_accumulation_steps=1 \
  --learning_rate=5e-6 \
  --lr_scheduler="constant" \
  --lr_warmup_steps=0 \
  --max_train_steps=400 #5000

# %%
#MODEL_NAME="stabilityai/stable-diffusion-2-inpainting"
#dataset_name="matterr/product-10k-part1"

#OUTPUT_DIR="/output/data_sample"

#!accelerate launch inpainting_train_edit.py \
  #--pretrained_model_name_or_path=$MODEL_NAME  \
  #--dataset_name=$dataset_name \
  #--output_dir=$OUTPUT_DIR \
  #--instance_prompt="a photo of sks dog" \
  #--resolution=512 \
  #--train_batch_size=1 \
  #--gradient_accumulation_steps=1 \
  #--learning_rate=5e-6 \
  #--lr_scheduler="constant" \
  #--lr_warmup_steps=0 \
  #--max_train_steps=400 #5000
